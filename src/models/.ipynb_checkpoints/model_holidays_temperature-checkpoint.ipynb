# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %% [markdown]
# ## Read Data

# %%
filename = "../data/data.csv"

# %%
df = pd.read_csv(filename)

# %%
df.count()
# Out:
# datetime       9041
# consumption    9041
# temp           9041
# dtype: int64

# %%
df.head()
# Out:
#                  datetime  consumption  temp
# 0  12/19/2018, 3:00:02 PM          249    69
# 1  12/19/2018, 4:00:03 PM          294    69
# 2  12/19/2018, 6:00:02 PM          287    69
# 3  12/19/2018, 7:00:02 PM          285    69
# 4  12/19/2018, 8:00:02 PM          228    69

# %% [markdown]
# ### Convert index to datetime

# %%
df = pd.read_csv(filename,index_col = 'datetime',parse_dates=['datetime'])
df.head(5)
# Out:
#                      consumption  temp
# datetime
# 2018-12-19 15:00:02          249    69
# 2018-12-19 16:00:03          294    69
# 2018-12-19 18:00:02          287    69
# 2018-12-19 19:00:02          285    69
# 2018-12-19 20:00:02          228    69

# %% [markdown]
# ### Verify that no value is null

# %%
df.isna().sum()
# Out:
# consumption    0
# temp           0
# dtype: int64

# %%
df['consumption'] = df['consumption'] + 1

# %%
min(df.consumption)
# Out:
# 1

# %% [markdown]
# # Energy Consumption vs Datetime Graph

# %%
df.plot(y=['consumption'],figsize=(12,5),legend=True)
plt.show()

# %% [markdown]
# # Temperature vs Datetime Graph

# %%
df.plot(y=['temp'],figsize=(12,5),legend=True)
plt.show()

# %% [markdown]
# ## Maximum Energy Consumption Values

# %%
df.nlargest(10,'consumption')
# Out:
#                      consumption  temp
# datetime
# 2019-05-16 12:00:02         1643    96
# 2019-05-16 11:00:01         1620    96
# 2019-05-21 15:00:02         1594    98
# 2019-05-21 16:00:02         1583    98
# 2019-05-22 14:00:02         1568    99
# 2019-05-22 15:00:02         1568    99
# 2019-05-22 12:00:01         1554    99
# 2019-05-22 13:00:02         1551    99
# 2019-05-10 15:00:02         1549    96
# 2019-05-22 16:00:01         1548    99

# %% [markdown]
# # Maximum Temperature Values (in °F)

# %%
df.nlargest(10,'temp')
# Out:
#                      consumption  temp
# datetime
# 2019-05-27 22:00:02          490   100
# 2019-05-27 23:00:02          484   100
# 2019-05-28 00:00:02          470   100
# 2019-05-28 01:00:02          464   100
# 2019-05-28 02:00:01          422   100
# 2019-05-28 03:00:02          389   100
# 2019-05-28 04:00:02          369   100
# 2019-05-28 05:00:02          304   100
# 2019-05-28 06:00:02          246   100
# 2019-05-28 07:00:01          402   100

# %%
df = df.reset_index()

# %%
df.count()
# Out:
# datetime       9041
# consumption    9041
# temp           9041
# dtype: int64

# %% [markdown]
# ## Changing dataframe format specific to Prophet Model

# %%
df = df.rename(columns={'datetime':'ds','consumption':'y'})

# %%
df.count()
# Out:
# ds      9041
# y       9041
# temp    9041
# dtype: int64

# %%
df.nlargest(10,'y')
# Out:
#                       ds     y  temp
# 3502 2019-05-16 12:00:02  1643    96
# 3501 2019-05-16 11:00:01  1620    96
# 3625 2019-05-21 15:00:02  1594    98
# 3626 2019-05-21 16:00:02  1583    98
# 3648 2019-05-22 14:00:02  1568    99
# 3649 2019-05-22 15:00:02  1568    99
# 3646 2019-05-22 12:00:01  1554    99
# 3647 2019-05-22 13:00:02  1551    99
# 3361 2019-05-10 15:00:02  1549    96
# 3650 2019-05-22 16:00:01  1548    99

# %% [markdown]
# ## Taking log of consumption values

# %%
df.y = np.log(df.y)

# %% [markdown]
# ## Model Fitting

# %%
model = Prophet()
model.add_country_holidays(country_name='IN')
model.add_regressor('temp')

# %%
model.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/kanish/.local/lib/python3.6/site-packages/fbprophet/hdays.py:259: Warning:
#
# We only support Diwali and Holi holidays from 2010 to 2030

# %% [markdown]
# # List of Holidays

# %%
model.train_holiday_names
# Out:
# 0                        Republic Day
# 1                    Independence Day
# 2                      Gandhi Jayanti
# 3                              Diwali
# 4                                Holi
# 5                       Day of Ashura
# 6                              Mawlid
# 7                         Eid al-Fitr
# 8              Feast of the Sacrifice
# 9                      New Year's Day
# 10                        Palm Sunday
# 11                    Maundy Thursday
# 12                        Good Friday
# 13                      Easter Sunday
# 14                 Feast of Pentecost
# 15    Fest of St. Theresa of Calcutta
# 16        Feast of the Blessed Virgin
# 17                     All Saints Day
# 18                      All Souls Day
# 19                      Christmas Day
# 20                         Boxing Day
# 21               Feast of Holy Family
# dtype: object

# %% [markdown]
# ## Predictions

# %%
prediction=model.predict(df)

# %%
org_prediction = prediction.copy()

# %%
prediction.nlargest(10,'yhat')
# Out:
#                       ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 3788 2019-05-28 10:00:02  5.640953    5.786549    9.012199     5.640953
# 3789 2019-05-28 11:00:01  5.640934    5.830153    8.963114     5.640934
# 3620 2019-05-21 10:00:02  5.619663    5.692595    8.856980     5.619663
# 3621 2019-05-21 11:00:02  5.619819    5.811715    8.875264     5.619819
# 3956 2019-06-04 10:00:02  5.637732    5.729656    8.868621     5.637732
# 3957 2019-06-04 11:00:03  5.637713    5.774514    8.867188     5.637713
# 4005 2019-06-06 11:00:02  5.636792    5.568512    8.846153     5.636792
# 4122 2019-06-11 10:00:02  5.627510    5.795282    8.909210     5.627510
# 3790 2019-05-28 12:00:02  5.640914    5.587157    8.811565     5.640914
# 4123 2019-06-11 11:00:02  5.627395    5.625431    8.740049     5.627395
#
#       trend_upper  All Saints Day  All Saints Day_lower  All Saints Day_upper  \
# 3788     5.640953             0.0                   0.0                   0.0
# 3789     5.640934             0.0                   0.0                   0.0
# 3620     5.619663             0.0                   0.0                   0.0
# 3621     5.619819             0.0                   0.0                   0.0
# 3956     5.637732             0.0                   0.0                   0.0
# 3957     5.637713             0.0                   0.0                   0.0
# 4005     5.636792             0.0                   0.0                   0.0
# 4122     5.627510             0.0                   0.0                   0.0
# 3790     5.640914             0.0                   0.0                   0.0
# 4123     5.627395             0.0                   0.0                   0.0
#
#       All Souls Day  ...      temp  temp_lower  temp_upper    weekly  \
# 3788            0.0  ...  0.257261    0.257261    0.257261  0.837413
# 3789            0.0  ...  0.257261    0.257261    0.257261  0.808317
# 3620            0.0  ...  0.227763    0.227763    0.227763  0.837413
# 3621            0.0  ...  0.227763    0.227763    0.227763  0.808309
# 3956            0.0  ...  0.183516    0.183516    0.183516  0.837413
# 3957            0.0  ...  0.183516    0.183516    0.183516  0.808300
# 4005            0.0  ...  0.109772    0.109772    0.109772  0.590742
# 4122            0.0  ...  0.139270    0.139270    0.139270  0.837413
# 3790            0.0  ...  0.257261    0.257261    0.257261  0.775640
# 4123            0.0  ...  0.139270    0.139270    0.139270  0.808309
#
#       weekly_lower  weekly_upper  multiplicative_terms  \
# 3788      0.837413      0.837413                   0.0
# 3789      0.808317      0.808317                   0.0
# 3620      0.837413      0.837413                   0.0
# 3621      0.808309      0.808309                   0.0
# 3956      0.837413      0.837413                   0.0
# 3957      0.808300      0.808300                   0.0
# 4005      0.590742      0.590742                   0.0
# 4122      0.837413      0.837413                   0.0
# 3790      0.775640      0.775640                   0.0
# 4123      0.808309      0.808309                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 3788                         0.0                         0.0  7.404698
# 3789                         0.0                         0.0  7.403266
# 3620                         0.0                         0.0  7.353910
# 3621                         0.0                         0.0  7.352629
# 3956                         0.0                         0.0  7.327733
# 3957                         0.0                         0.0  7.326250
# 4005                         0.0                         0.0  7.280229
# 4122                         0.0                         0.0  7.273264
# 3790                         0.0                         0.0  7.273086
# 4123                         0.0                         0.0  7.271712
#
# [10 rows x 94 columns]

# %% [markdown]
# ### Let's check for effect of Gandhi Jayanti on Energy consumption value

# %%
prediction.nlargest(10,'Gandhi Jayanti')[['ds','Gandhi Jayanti']]
# Out:
#                       ds  Gandhi Jayanti
# 6752 2019-10-02 00:00:01        0.026672
# 6753 2019-10-02 01:00:02        0.026672
# 6754 2019-10-02 02:00:01        0.026672
# 6755 2019-10-02 03:00:02        0.026672
# 6756 2019-10-02 04:00:02        0.026672
# 6757 2019-10-02 05:00:02        0.026672
# 6758 2019-10-02 06:00:02        0.026672
# 6759 2019-10-02 07:00:02        0.026672
# 6760 2019-10-02 08:00:01        0.026672
# 6761 2019-10-02 09:00:02        0.026672

# %% [markdown]
# # Actual vs Predicted Energy Values Plot
# Black points represents the actual values, blue  points represents the predicted values and the light blue margin represents the lower and upper bound of predicted values for certain points.

# %%
fig = model.plot(prediction)

# %% [markdown]
# ## Monthly, Daywise and Timewise distribution

# %% [markdown]
# The values in the graph basically represents the effect of values corresponding to x-axis on result predicted on y-axis

# %%
fig = model.plot_components(prediction)
# Out:
# /home/kanish/.local/lib/python3.6/site-packages/fbprophet/hdays.py:259: Warning:
#
# We only support Diwali and Holi holidays from 2010 to 2030
#
# /home/kanish/.local/lib/python3.6/site-packages/fbprophet/hdays.py:259: Warning:
#
# We only support Diwali and Holi holidays from 2010 to 2030

# %%
df.head()
# Out:
#                    ds         y  temp
# 0 2018-12-19 15:00:02  5.521461    69
# 1 2018-12-19 16:00:03  5.686975    69
# 2 2018-12-19 18:00:02  5.662960    69
# 3 2018-12-19 19:00:02  5.655992    69
# 4 2018-12-19 20:00:02  5.433722    69

# %%
prediction.head()
# Out:
#                    ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0 2018-12-19 15:00:02  4.000812    3.269851    6.228088     4.000812
# 1 2018-12-19 16:00:03  4.001517    3.281044    6.432613     4.001517
# 2 2018-12-19 18:00:02  4.002926    3.077608    6.181566     4.002926
# 3 2018-12-19 19:00:02  4.003631    2.799176    5.912062     4.003631
# 4 2018-12-19 20:00:02  4.004336    2.546750    5.864165     4.004336
#
#    trend_upper  All Saints Day  All Saints Day_lower  All Saints Day_upper  \
# 0     4.000812             0.0                   0.0                   0.0
# 1     4.001517             0.0                   0.0                   0.0
# 2     4.002926             0.0                   0.0                   0.0
# 3     4.003631             0.0                   0.0                   0.0
# 4     4.004336             0.0                   0.0                   0.0
#
#    All Souls Day  ...      temp  temp_lower  temp_upper    weekly  \
# 0            0.0  ... -0.199954   -0.199954   -0.199954  0.348177
# 1            0.0  ... -0.199954   -0.199954   -0.199954  0.370681
# 2            0.0  ... -0.199954   -0.199954   -0.199954  0.417761
# 3            0.0  ... -0.199954   -0.199954   -0.199954  0.441530
# 4            0.0  ... -0.199954   -0.199954   -0.199954  0.464917
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0      0.348177      0.348177                   0.0
# 1      0.370681      0.370681                   0.0
# 2      0.417761      0.417761                   0.0
# 3      0.441530      0.441530                   0.0
# 4      0.464917      0.464917                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  4.785256
# 1                         0.0                         0.0  4.821819
# 2                         0.0                         0.0  4.535848
# 3                         0.0                         0.0  4.335331
# 4                         0.0                         0.0  4.187794
#
# [5 rows x 94 columns]

# %% [markdown]
# ## Errors

# %%
true_val = np.exp(df.y)

# %%
pred_val = np.exp(org_prediction['yhat'])

# %%
mean_squared_error(y_true=true_val,y_pred=pred_val)
# Out:
# 40385.480516098345

# %%
mean_absolute_error(y_true=true_val,y_pred=pred_val)
# Out:
# 136.9602552391028

# %% [markdown]
# ## Prediction

# %%
data = ['2019-05-16 12:00:00']
test = pd.DataFrame(data, columns = ['ds'])

# %%
test['temp'] = 80

# %%
test
# Out:
#                     ds  temp
# 0  2019-05-16 12:00:00    80

# %%
val = model.predict(test)
# Out:
# /home/kanish/.local/lib/python3.6/site-packages/fbprophet/hdays.py:259: Warning:
#
# We only support Diwali and Holi holidays from 2010 to 2030

# %%
val
# Out:
#                    ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0 2019-05-16 12:00:00  5.601266     5.19957    8.375206     5.601266
#
#    trend_upper  All Saints Day  All Saints Day_lower  All Saints Day_upper  \
# 0     5.601266             0.0                   0.0                   0.0
#
#    All Souls Day  ...      temp  temp_lower  temp_upper    weekly  \
# 0            0.0  ... -0.037716   -0.037716   -0.037716  0.580464
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0      0.580464      0.580464                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  6.743345
#
# [1 rows x 94 columns]

# %%
np.exp(val['yhat'])
# Out:
# 0    848.393556
# Name: yhat, dtype: float64

# %% [markdown]
# ## Saving Model

# %%
type(model)
# Out:
# fbprophet.forecaster.Prophet

# %%
pkl_path = "model.pkl"

# %%
model.stan_backend.logger = None

# %%
with open(pkl_path, 'wb') as fout:
    pickle.dump(model, fout)

# %%
with open('model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)
